# %% [markdown]
# # Corona Analysis in Germany
#
# ### Please refer to my name and email address when you want to use the plots that are presented in this Jupyter Notebook.
#
# #### Maryam Arabshahi
# #### arabshahi.ma@gmail.com

# %%
from PIL import Image
Image.open('./images/cases.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=838x545 at 0x7F9F6C4BC1D0>

# %%
Image.open('./images/gender.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=831x437 at 0x7F9F6C0FD1D0>

# %%
Image.open('./images/patients_vs_deads.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=846x497 at 0x7F9F6C0FD2B0>

# %%
Image.open('./images/heatmap.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=894x539 at 0x7F9F6C0FD278>

# %%
Image.open('./images/population_patient_RP.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1066x668 at 0x7F9F6C0FD240>

# %% [markdown]
# ### sources:
# #### 1. https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Fallzahlen.html
# #### 2. https://npgeo-corona-npgeo-de.hub.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0/data?page=13
